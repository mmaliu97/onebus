# %%
from shapely import wkt
import geopandas as gpd
from shapely.geometry import Point
import pandas as pd
import matplotlib.pyplot as plt

# %%
unique_stops_df = pd.read_csv("C:/Users/Martin/Coding Projects/One Bus/onebus/all_unique_stops.csv")
filtered_poi_df = pd.read_csv("C:/Users/Martin/Coding Projects/One Bus/onebus/filtered_pois.csv")

# %%
filtered_poi_df['geometry']
# Out:
# 0       POINT (-97.75270603052614 30.269497787495215)
# 1                          POINT (-97.785977 30.2407)
# 2                      POINT (-97.7471061 30.2672548)
# 3                      POINT (-97.7503681 30.2703425)
# 4                      POINT (-97.7245889 30.2687467)
#                             ...
# 1902    POINT (-97.74163177339076 30.385981088512377)
# 1903    POINT (-97.70208610407877 30.423703732464404)
# 1904                   POINT (-97.7890813 30.4444398)
# 1905    POINT (-97.79138927022609 30.457187195731564)
# 1906                   POINT (-97.7329038 30.3888001)
# Name: geometry, Length: 1907, dtype: object

# %%
# Convert string to Point geometry
gdf = filtered_poi_df.copy()
gdf['geometry'] = gdf['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(gdf, geometry='geometry')

# Now plot
gdf.plot()
# Out:
# <Axes: >

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot first GeoDataFrame
gdf1.plot(ax=ax1, color='blue', alpha=0.5, edgecolor='black')
ax1.set_title('GeoDataFrame 1')
ax1.set_axis_off()

# Plot second GeoDataFrame
gdf2.plot(ax=ax2, color='red', alpha=0.5, edgecolor='black')
ax2.set_title('GeoDataFrame 2')
ax2.set_axis_off()

plt.tight_layout()
plt.show()
